# %%
#!git clone https://github.com/Jqiu149/Int2Int.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pickle
import matplotlib.pyplot as plt
import glob
import ast
from datetime import datetime
from tabulate import tabulate

import numpy as np

#import tikzplotlib
from IPython.core.display import HTML

display(HTML("<style>.container {width:90% !important;}</style>"))
display(HTML("<style>pre { white-space: pre !important; }</style>"))
from operator import itemgetter

# path and env name
path = '/content/drive/MyDrive/example+trained_model_data/'
stderr_path= ""

xp_env = ["add"]

indicator = "valid_arithmetic"

xp_id_filter=[]
xp_id_selector=[]
unwanted_args = ['dump_path']

# global variables
var_args = set()
all_args = {}


# list experiments
xps = [(env, xp) for env in xp_env for xp in os.listdir(path+'/'+env) if (len(xp_id_selector)==0 or xp in xp_id_selector) and (len(xp_id_filter)==0 or not xp in xp_id_filter)]
names = [path + env + '/' + xp for (env, xp) in xps]
print(len(names),"experiments found")

# read all args
pickled_xp = 0
for name in names:
    pa = name+'/params.pkl'
    if not os.path.exists(pa):
        print("Unpickled experiment: ", name)
        continue
    pk = pickle.load(open(pa,'rb'))
    print(pk)
    all_args.update(pk.__dict__)
    pickled_xp += 1
print(pickled_xp, "pickled experiments found")
print()

# find variable args
for name in names:
    pa = name+'/params.pkl'
    if not os.path.exists(pa):
        continue
    pk = pickle.load(open(pa,'rb'))
    for key,value in all_args.items():
        if key in pk.__dict__ and value == pk.__dict__[key]:
            continue
        if key not in unwanted_args:
            var_args.add(key)

print("common args")
for key in all_args:
    if key not in unwanted_args and key not in var_args:
        print(key,"=", all_args[key])
print()

print(len(var_args)," variables params out of", len(all_args))
print(var_args)
# Out:
# <style>.container {width:90% !important;}</style>
# <style>pre { white-space: pre !important; }</style>
# 22 experiments found
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/max-1000000_default-rep_base-10', exp_name='add', save_periodic=0, exp_id='max-1000000_default-rep_base-10', report_loss_every=200, epoch_size=300000, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='modular_add', data_types='', dim1=10, dim2=10, maxint=100, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=3000000, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=True, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/max-1000000000000000_default-rep_base-10', exp_name='add', save_periodic=0, exp_id='max-1000000000000000_default-rep_base-10', report_loss_every=200, epoch_size=300000, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='modular_add', data_types='', dim1=10, dim2=10, maxint=1000000000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=3000000000000000, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/max-10000-default-rep', exp_name='add', save_periodic=0, exp_id='max-10000-default-rep', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='modular_add', data_types='', dim1=10, dim2=10, maxint=10000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=1000, modulus=20001, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/maxint1000000000000000_default-rep_base2', exp_name='add', save_periodic=0, exp_id='maxint1000000000000000_default-rep_base2', report_loss_every=200, epoch_size=300000, max_epoch=2, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='modular_add', data_types='', dim1=10, dim2=10, maxint=1000000000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=2, modulus=30000000000000000, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/maxint1000000000000000_type3modifiedrep_base10', exp_name='add', save_periodic=0, exp_id='maxint1000000000000000_type3modifiedrep_base10', report_loss_every=200, epoch_size=300000, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add3', data_types='', dim1=10, dim2=10, maxint=1000000000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/maxint1000000_type2modifiedrep_base10', exp_name='add', save_periodic=0, exp_id='maxint1000000_type2modifiedrep_base10', report_loss_every=200, epoch_size=300000, max_epoch=3, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add2', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/maxint1000000000000000_type2modifiedrep_base10', exp_name='add', save_periodic=0, exp_id='maxint1000000000000000_type2modifiedrep_base10', report_loss_every=200, epoch_size=300000, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add2', data_types='', dim1=10, dim2=10, maxint=1000000000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/max-1000000_rep3_base-10', exp_name='add', save_periodic=0, exp_id='max-1000000_rep3_base-10', report_loss_every=200, epoch_size=300000, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=10000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add3', data_types='', dim1=10, dim2=10, maxint=1000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=True, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint-100000-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint-100000-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add4-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint-100000-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_maxint-100000-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add4-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint-100000-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint10000000000-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint10000000000-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add4-rev', data_types='', dim1=10, dim2=10, maxint=10000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train10000000000-training_eval100000000000', exp_name='add', save_periodic=0, exp_id='one-step_train10000000000-training_eval100000000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=True, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='add4-rev', data_types='', dim1=10, dim2=10, maxint=100000000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint10000000000-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.2-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint100000-dropout0.2-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.05, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train100000-dropout0.2-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_train100000-dropout0.2-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.2, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.2-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.2-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint100000-dropout0.2-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.2, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train100000-dropout0.2-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_train100000-dropout0.2-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.2, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.2-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.5-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint100000-dropout0.5-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train100000-dropout0.5-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_train100000-dropout0.5-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.5-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.5-attentionDropOut0.5-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint100000-dropout0.5-attentionDropOut0.5-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0.5, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0.5, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-dropout0.5-attentionDropOut0.5-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-attentionDropOut0.5-training', exp_name='add', save_periodic=0, exp_id='one-step_maxint100000-attentionDropOut0.5-training', report_loss_every=200, epoch_size=6400, max_epoch=1, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0.5, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=100000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='', reload_checkpoint='', eval_only=False, eval_from_exp='', eval_data='', eval_verbose=0, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# Namespace(dump_path='/content/drive/MyDrive/example+trained_model_data/add/one-step_train100000-attentionDropOut-training_eval1000000', exp_name='add', save_periodic=0, exp_id='one-step_train100000-attentionDropOut-training_eval1000000', report_loss_every=200, epoch_size=300000, max_epoch=100000, stopping_criterion='', validation_metrics='', enc_emb_dim=256, dec_emb_dim=256, n_enc_layers=4, n_dec_layers=4, n_enc_heads=8, n_dec_heads=8, xav_init=False, n_enc_hidden_layers=1, n_dec_hidden_layers=1, gelu_activation=False, dropout=0.5, max_src_len=0, norm_attention=False, attention_dropout=0.5, architecture='encoder_decoder', lstm=False, GRU=False, bidirectional=False, lstm_hidden_dim=2048, share_inout_emb=True, sinusoidal_embeddings=False, enc_has_pos_emb=True, dec_has_pos_emb=True, enc_loop_idx=-1, dec_loop_idx=-1, enc_loops=1, dec_loops=1, gated=False, enc_gated=False, dec_gated=False, scalar_gate=False, biased_gates=False, gate_bias=0, enc_act=False, dec_act=False, act_threshold=0.01, act_ponder_coupling=0.01, act_biased=False, act_bias=0, fp16=False, amp=-1, num_workers=1, env_base_seed=-1, cpu=False, local_gpu=-1, local_rank=0, master_port=-1, max_len=512, max_output_len=512, eval_size=3000, batch_size_eval=128, batch_size=32, accumulate_gradients=1, optimizer='adam,lr=0.0001', clip_grad_norm=5, export_data=False, train_data='', reload_size=-1, batch_load=False, env_name='arithmetic', operation='oneStepAdd-rev', data_types='', dim1=10, dim2=10, maxint=1000000, minint=1, two_classes=False, first_class_size=1000000, first_class_prob=0.25, base=10, modulus=67, n_eval_metrics=0, n_error_metrics=0, export_pred=False, max_class=101, tasks='arithmetic', beam_eval=False, beam_eval_train=0, beam_size=1, beam_length_penalty=1, beam_early_stopping=True, reload_model='/content/drive/MyDrive/example+trained_model_data/add/one-step_maxint100000-attentionDropOut0.5-training/checkpoint.pth', reload_checkpoint='', eval_only=True, eval_from_exp='', eval_data='', eval_verbose=1, eval_verbose_print=False, debug_slurm=False, debug=False, is_slurm_job=False, n_nodes=1, node_id=0, global_rank=0, world_size=1, n_gpu_per_node=1, is_master=True, multi_node=False, multi_gpu=False)
# 22 pickled experiments found
#
# common args
# exp_name = add
# save_periodic = 0
# report_loss_every = 200
# stopping_criterion =
# validation_metrics =
# enc_emb_dim = 256
# dec_emb_dim = 256
# n_enc_layers = 4
# n_dec_layers = 4
# n_enc_heads = 8
# n_dec_heads = 8
# xav_init = False
# n_enc_hidden_layers = 1
# n_dec_hidden_layers = 1
# gelu_activation = False
# max_src_len = 0
# norm_attention = False
# architecture = encoder_decoder
# lstm = False
# GRU = False
# bidirectional = False
# lstm_hidden_dim = 2048
# share_inout_emb = True
# sinusoidal_embeddings = False
# enc_has_pos_emb = True
# dec_has_pos_emb = True
# enc_loop_idx = -1
# dec_loop_idx = -1
# enc_loops = 1
# dec_loops = 1
# gated = False
# enc_gated = False
# dec_gated = False
# scalar_gate = False
# biased_gates = False
# gate_bias = 0
# enc_act = False
# dec_act = False
# act_threshold = 0.01
# act_ponder_coupling = 0.01
# act_biased = False
# act_bias = 0
# fp16 = False
# amp = -1
# num_workers = 1
# env_base_seed = -1
# local_gpu = -1
# local_rank = 0
# master_port = -1
# max_len = 512
# max_output_len = 512
# batch_size_eval = 128
# batch_size = 32
# accumulate_gradients = 1
# optimizer = adam,lr=0.0001
# clip_grad_norm = 5
# export_data = False
# train_data =
# reload_size = -1
# batch_load = False
# env_name = arithmetic
# data_types =
# dim1 = 10
# dim2 = 10
# minint = 1
# two_classes = False
# first_class_size = 1000000
# first_class_prob = 0.25
# n_eval_metrics = 0
# n_error_metrics = 0
# export_pred = False
# max_class = 101
# tasks = arithmetic
# beam_eval = False
# beam_eval_train = 0
# beam_size = 1
# beam_length_penalty = 1
# beam_early_stopping = True
# reload_checkpoint =
# eval_from_exp =
# eval_data =
# debug_slurm = False
# debug = False
# is_slurm_job = False
# n_nodes = 1
# node_id = 0
# global_rank = 0
# world_size = 1
# n_gpu_per_node = 1
# is_master = True
# multi_node = False
# multi_gpu = False
#
# 15  variables params out of 108
# {'eval_verbose', 'dropout', 'max_epoch', 'operation', 'reload_model', 'epoch_size', 'base', 'modulus', 'attention_dropout', 'eval_size', 'maxint', 'eval_verbose_print', 'exp_id', 'cpu', 'eval_only'}

# %%
#... ig gives dictionary for values of variable args for the experiemnt passed in?
def vars_from_env_xp(env, xp):
    res = {}
    pa = path+env+'/'+xp+'/params.pkl'
    if not os.path.exists(pa):
        print("pickle", pa, "not found")
        return res
    pk = pickle.load(open(pa,'rb'))
    for key in var_args:
        if key in pk.__dict__:
            res[key] = pk.__dict__[key]
        else:
            res[key] = None
    return res


def get_start_time(line):
    parsed_line = line.split(" ")
    dt = datetime.strptime(parsed_line[2]+' '+parsed_line[3],"%m/%d/%y %H:%M:%S")
    try:
        idx = parsed_line.index("epoch")
        curr_epoch = int(parsed_line[idx+1])
    except ValueError:
        curr_epoch = ""
    return dt, curr_epoch


def read_xp(env, xp, indics, max_epoch=None):
    res = {"env":env, "xp": xp, "stderr":False, "log":False, "error":False}
    stderr_file = stderr_path+env+'/*/'+xp+'.stderr'
    nb_stderr =len(glob.glob(stderr_file))
    if nb_stderr > 1:
        print("duplicate stderr", env, xp)
        return res
    for name in glob.glob(stderr_file):
        with open(name, 'rt') as f:
            res["stderr"]=True
            errlines = []
            cuda = False
            terminated = False
            forced = False
            for line in f:
                if line.find("RuntimeError:") >= 0:
                    errlines.append(line)
                if line.find("CUDA out of memory") >= 0:
                    cuda = True
                if line.find("Exited with exit code 1") >=0:
                    # print(stderr_file)
                    terminated = True

                if line.find("Force Terminated") >=0:
                    # print(stderr_file)
                    forced = True
            res["forced"] = forced

            res["terminated"] = terminated
            if len(errlines) > 0:
                res["error"] = True
                res["runtime_errors"] = errlines
                res["oom"] = cuda
                if not cuda:
                    print(stderr_file,"runtime error no oom")

    pa = path+env+'/'+xp+'/train.log'
#    print(pa)
    if not os.path.exists(pa):
        return res
    res["log"] = True
    with open(pa, 'rt') as f:
        series = []
        train_loss=[]
        for ind in indics:
            series.append([])
        best_val = -1.0
        best_xel = 999999999.0
        best_epoch = -1
        epoch = -1
        val = -1
        ended = False
        nanfound = False
        res["curr_epoch"]=-1
        res["train_time"]=0
        res["eval_time"]=0
        res["pred_nr"]=[]
        nb_sig10 = 0
        nb_sig15 = 0
        counter = 0
        counting = False
        for line in f:
            try:
                if counting:
                    counter += 1
                if line.find("Signal handler called with signal 10") >= 0:
                    nb_sig10 += 1
                if line.find("Signal handler called with signal 15") >= 0:
                    nb_sig15 += 1
                if line.find("Stopping criterion has been below its best value for more than") >=0:
                    ended = True
                elif line.find("============ Starting epoch") >=0:
                    dt, curr_epoch = get_start_time(line)
                    if curr_epoch == max_epoch: break
                    res["start_time"] = dt
                    if curr_epoch >0 and curr_epoch == res["curr_epoch"]+1:
                        res["eval_time"] += (dt - res["end_time"]).total_seconds()
                    res["curr_epoch"] = curr_epoch
                elif line.find("============ End of epoch") >=0:
                    dt, curr_epoch = get_start_time(line)
                    if curr_epoch != res["curr_epoch"]:
                        print("epoch mismatch", curr_epoch,"in", env,",", xp)
                    else:
                        res["end_time"] = dt
                        res["train_time"] += (dt-res["start_time"]).total_seconds()
                elif line.find("- model LR:") >=0:
                    loss = line.split(" ")[-5].strip()
                    train_loss.append(None if loss == 'nan' else float(loss))
                elif line.find("- LR:") >=0:
                    loss = line.split(" ")[-4].strip()
                    if loss == "predictions.":
                        print(line)
                    else:
                        train_loss.append(None if loss == 'nan' else float(loss))
                elif line.find('- test predicted pairs') >=0:
                    counter = 0
                    counting = True
                else:
                    pos = line.find('__log__:')
                    if pos >=0:
                        counting = False
                        res['pred_nr'].append(counter/100.0)
                        if line[pos+8:].find(': NaN,') >= 0:
                            nanfound = True
                            line = line.replace(': NaN,',': -1.0,')
                        dic = ast.literal_eval(line[pos+8:])
                        epoch = dic["epoch"]
                        if not indicator+"_"+indics[0] in dic:
                            continue
                        if not indicator+"_"+indics[1] in dic:
                            continue
                        val = dic[indicator+"_"+indics[0]]
                        xel = dic[indicator+"_"+indics[1]]
                        if xel < best_xel:
                            best_xel= xel
                        if val > best_val:
                            best_val = val
                            best_epoch = epoch
                            res["best_dic"] = dic
                        for i, indic in enumerate(indics):
                            if indicator+"_"+indic in dic:
                                series[i].append(dic[indicator+"_"+indic])

            except Exception as e:
                print(e, "exception in", env, xp)
                continue
            except:
                print(line)
                continue
        res["nans"] = nanfound
        res["ended"] = (ended or (nb_sig15 > nb_sig10))
        res["last_epoch"] = epoch
        res["last_acc"] = "{:.2f}".format(val)
        res["best_epoch"] = best_epoch
        res["best_acc"] = float("{:.2f}".format(best_val))
        res["best_xeloss"] = "{:.2f}".format(best_xel)
        res["train_loss"]=train_loss
        res["avg_d"] = np.median(res['pred_nr'])
        res["last_d"] = res['pred_nr'][-1] if len(res['pred_nr']) > 0 else -1
        if epoch >=0:
            res["train_time"] /= (epoch+1)
            res["eval_time"] /= (epoch+1)
        res["train_time"] = int(res["train_time"]+0.5)
        res["eval_time"] = int(res["eval_time"]+0.5)

        for i,indic in enumerate(indics):
            res["last_"+indic] = "{:.2f}".format(series[i][-1]) if len(series[i])>0 else '0'
            res["best_"+indic] = "{:.2f}".format(max(series[i])) if len(series[i])>0 else '0'
            res[indic] = series[i]
            if len(series[i])!= epoch + 1:
                print("mismatch in nr of epochs",env, xp, epoch+1, len(series[i]), indic)
    return res



# read experiments
data = []

#IF ADD TO 'indics' array, ADD TO END NOT FRONT. WILL BREAK STUFF IF ADD TO FRONT...
#also reminder that they're like assuming we have valid_arithmetic in front of these in the actual train logs... but don't need to include that here
indics = ["acc","xe_loss", "perfect", "correct", "acc_6"]
for (env, xp) in xps:
    res = read_xp(env, xp, indics, None)
    res.update(vars_from_env_xp(env, xp))
    data.append(res)

print(len(data), "experiments read")
print(len([d for d in data if d["stderr"] is False]),"stderr not found")
print(len([d for d in data if d["error"] is True]),"runtime errors")
print(len([d for d in data if "oom" in d and d["oom"] is True]),"oom errors")
print(len([d for d in data if "terminated" in d and d["terminated"] is True]),"exit code 1")
print(len([d for d in data if "forced" in d and d["forced"] is True]),"Force Terminated")
print(len([d for d in data if "last_epoch" in d and d["last_epoch"] >= 0]),"started XP")
print(len([d for d in data if "ended" in d and d["ended"] is True]),"ended XP")
print(len([d for d in data if "best_acc" in d and float(d["best_acc"]) > 0.0]),"began predicting")
# Out:
# mismatch in nr of epochs add max-1000000_default-rep_base-10 2 0 acc_6
# mismatch in nr of epochs add max-1000000000000000_default-rep_base-10 6 0 acc_6
# mismatch in nr of epochs add max-10000-default-rep-base1000 7 0 acc_6
# mismatch in nr of epochs add maxint1000000000000000_default-rep_base2 5 0 acc_6
# mismatch in nr of epochs add one-step_maxint-100000-training 13 0 acc_6
# mismatch in nr of epochs add one-step_maxint-100000-training_eval1000000 1 13 acc
# mismatch in nr of epochs add one-step_maxint-100000-training_eval1000000 1 13 xe_loss
# mismatch in nr of epochs add one-step_maxint-100000-training_eval1000000 1 13 perfect
# mismatch in nr of epochs add one-step_maxint-100000-training_eval1000000 1 13 correct
# mismatch in nr of epochs add one-step_maxint-100000-training_eval1000000 1 13 acc_6
# mismatch in nr of epochs add one-step_train10000000000-training_eval100000000000 1 9 acc
# mismatch in nr of epochs add one-step_train10000000000-training_eval100000000000 1 9 xe_loss
# mismatch in nr of epochs add one-step_train10000000000-training_eval100000000000 1 9 perfect
# mismatch in nr of epochs add one-step_train10000000000-training_eval100000000000 1 9 correct
# mismatch in nr of epochs add one-step_train10000000000-training_eval100000000000 1 9 acc_6
# mismatch in nr of epochs add one-step_maxint100000-dropout0.05-training 8 0 acc_6
# mismatch in nr of epochs add one-step_train100000-dropout0.05-training_eval1000000 1 8 acc
# mismatch in nr of epochs add one-step_train100000-dropout0.05-training_eval1000000 1 8 xe_loss
# mismatch in nr of epochs add one-step_train100000-dropout0.05-training_eval1000000 1 8 perfect
# mismatch in nr of epochs add one-step_train100000-dropout0.05-training_eval1000000 1 8 correct
# mismatch in nr of epochs add one-step_train100000-dropout0.05-training_eval1000000 1 8 acc_6
# mismatch in nr of epochs add one-step_maxint100000-dropout0.2-training 7 0 acc_6
# mismatch in nr of epochs add one-step_train100000-dropout0.2-training_eval1000000 1 7 acc
# mismatch in nr of epochs add one-step_train100000-dropout0.2-training_eval1000000 1 7 xe_loss
# mismatch in nr of epochs add one-step_train100000-dropout0.2-training_eval1000000 1 7 perfect
# mismatch in nr of epochs add one-step_train100000-dropout0.2-training_eval1000000 1 7 correct
# mismatch in nr of epochs add one-step_train100000-dropout0.2-training_eval1000000 1 7 acc_6
# mismatch in nr of epochs add one-step_maxint100000-dropout0.5-training 13 0 acc_6
# mismatch in nr of epochs add one-step_train100000-dropout0.5-training_eval1000000 1 13 acc
# mismatch in nr of epochs add one-step_train100000-dropout0.5-training_eval1000000 1 13 xe_loss
# mismatch in nr of epochs add one-step_train100000-dropout0.5-training_eval1000000 1 13 perfect
# mismatch in nr of epochs add one-step_train100000-dropout0.5-training_eval1000000 1 13 correct
# mismatch in nr of epochs add one-step_train100000-dropout0.5-training_eval1000000 1 13 acc_6
# mismatch in nr of epochs add one-step_maxint100000-dropout0.5-attentionDropOut0.5-training 21 0 acc_6
# mismatch in nr of epochs add one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 1 21 acc
# mismatch in nr of epochs add one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 1 21 xe_loss
# mismatch in nr of epochs add one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 1 21 perfect
# mismatch in nr of epochs add one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 1 21 correct
# mismatch in nr of epochs add one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 1 21 acc_6
# mismatch in nr of epochs add one-step_maxint100000-attentionDropOut0.5-training 25 0 acc_6
# mismatch in nr of epochs add one-step_train100000-attentionDropOut-training_eval1000000 1 27 acc
# mismatch in nr of epochs add one-step_train100000-attentionDropOut-training_eval1000000 1 27 xe_loss
# mismatch in nr of epochs add one-step_train100000-attentionDropOut-training_eval1000000 1 27 perfect
# mismatch in nr of epochs add one-step_train100000-attentionDropOut-training_eval1000000 1 27 correct
# mismatch in nr of epochs add one-step_train100000-attentionDropOut-training_eval1000000 1 27 acc_6
# 22 experiments read
# 22 stderr not found
# 0 runtime errors
# 0 oom errors
# 0 exit code 1
# 0 Force Terminated
# 22 started XP
# 0 ended XP
# 21 began predicting

# %%
import numpy as np


def compose(f,g):
    return lambda x : f(g(x))

def print_table(data, args, sort=False, tablefmt = "pretty"):
    res = []
    for d in data:
        line = [d[v] if v in d else None for v in args]
        res.append(line)
    if sort:
        res = sorted(res, key=compose(float,itemgetter(0)), reverse=True)
    print(tabulate(res,headers=args,tablefmt="pretty"))



def speed_table(data, args, indic, sort=False, percent=95):
    res = []
    for d in data:

        if indic in d:
            line = [d[v] if v in d else None for v in args]
            val= 10000
            for i,v in enumerate(d[indic]):
                if v >= percent and i < val:
                    val = i

            line.insert(1,val)
            res.append(line)
    e= args.copy()
    e.insert(1,'first epoch')
    if sort:
        res = sorted(res, key=compose(float,itemgetter(1)), reverse=False)
    print(tabulate(res,headers=e,tablefmt="pretty"))


def training_curve(data, indic, beg=0, end=-1, maxval=None, minval=None, export_to=""):
    for d in data:
        if indic in d:
            if end == -1:
                plt.plot(d[indic][beg:],linewidth=1, label = d['env'] +'--'+ d['xp'])
            else:
                plt.plot(d[indic][beg:end],linewidth=1)
    plt.ylim(minval,maxval)
    plt.rcParams['figure.figsize'] = [10,10]
    if export_to != '':
       # print(export_to)
        plt.savefig(export_to,bbox_inches="tight")
    print(indic)
    plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
    plt.show()


def filter_xp(xp, filt):
    for f in filt:
        if not f in xp:
            return False
        if not xp[f] in filt[f]:
            return False
    return True

def xp_stats(data, splits, best_arg, best_value):
    res_dic = {}
    nb = 0
    for d in data:
        if d[best_arg] < best_value: continue
        nb += 1
        for s in splits:
            if not s in d: continue
            lib=s+':'+str(d[s])
            if lib in res_dic:
                res_dic[lib] += 1
            else:
                res_dic[lib]=1

    print()
    print(f"{nb} experiments with accuracy over {best_value}")
    for elem in sorted(res_dic):
        print(elem,' : ',res_dic[elem])
    print()

xp_filter ={}

#xp_filter.update({"n_enc_layers":[4]})
#xp_filter.update({"enc_emb_dim":[128]})


fdata = [d for d in data if filter_xp(d, xp_filter) is True]

oomtab = [d for d in fdata if d["error"] is True]
print(f"CUDA out of memory ({len(oomtab)})")
print_table(oomtab, var_args)

forcetab = [d for d in fdata if 'forced' in d and d["forced"] is True]
print(f"Forced terminations ({len(forcetab)})")
print_table(forcetab, var_args)

unstartedtab = [d for d in fdata if "last_epoch" in d and d["last_epoch"] < 0]
print(f"Not started ({len(unstartedtab)})")
print_table(unstartedtab, var_args)

crypto = False
runargs = ["best_acc", "best_epoch","best_xeloss",  "ended", "last_epoch", "last_acc", "last_xe_loss","nans", "error", "train_time", "eval_time"]
runargs.extend(["best_correct", "best_perfect"])
for v in var_args:
    runargs.append(v)
runningtab = [d for d in fdata if "last_epoch" in d and d["last_epoch"] >= 0]
print(f"Running experiments ({len(runningtab)})")

#splits = ['n_enc_layers','dec_emb_dim','reload_size']
#xp_stats(fdata, splits, 'best_acc',90.0)
print()





# if we want custom runarrgs/table outputs uncomment below ig
# runargs = ["exp_id", "best_acc", "best_xeloss", "last_acc", "last_xe_loss"]
# print_table(runningtab, runargs, sort=False, tablefmt = "latex")


print_table(runningtab, runargs, sort=True)

training_curve(fdata, "acc")

training_curve(fdata, "perfect")
training_curve(fdata, "correct")
training_curve(fdata, "xe_loss", 0) #, None, 0.9* np.min([x for d in fdata for x in d["xe_loss"] if x >0.0]))
training_curve(fdata, "train_loss",0,-1)

training_curve(fdata, "acc_6")


speed_table(runningtab, runargs, "acc", sort=True,percent=99)
speed_table(runningtab, runargs, "acc", sort=True,percent=50)
# Out:
# CUDA out of memory (0)
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# | eval_verbose | dropout | max_epoch | operation | reload_model | epoch_size | base | modulus | attention_dropout | eval_size | maxint | eval_verbose_print | exp_id | cpu | eval_only |
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# Forced terminations (0)
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# | eval_verbose | dropout | max_epoch | operation | reload_model | epoch_size | base | modulus | attention_dropout | eval_size | maxint | eval_verbose_print | exp_id | cpu | eval_only |
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# Not started (0)
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# | eval_verbose | dropout | max_epoch | operation | reload_model | epoch_size | base | modulus | attention_dropout | eval_size | maxint | eval_verbose_print | exp_id | cpu | eval_only |
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# +--------------+---------+-----------+-----------+--------------+------------+------+---------+-------------------+-----------+--------+--------------------+--------+-----+-----------+
# Running experiments (22)
#
# +-----------------------------------------------------------------------+----------+-------------+----------+--------------+
# |                                exp_id                                 | best_acc | best_xeloss | last_acc | last_xe_loss |
# +-----------------------------------------------------------------------+----------+-------------+----------+--------------+
# |                    max-1000000_default-rep_base-10                    |  96.24   |    0.20     |  96.24   |     0.20     |
# |               max-1000000000000000_default-rep_base-10                |  96.93   |    0.42     |  96.93   |     0.42     |
# |                         max-10000-default-rep                         |   5.85   |    3.40     |   5.85   |     3.40     |
# |               maxint1000000000000000_default-rep_base2                |   0.00   |    30.30    |   0.00   |    30.30     |
# |            maxint1000000000000000_type3modifiedrep_base10             |  99.41   |    0.04     |  98.30   |     0.07     |
# |                 maxint1000000_type2modifiedrep_base10                 |  95.68   |    0.19     |  95.68   |     0.19     |
# |            maxint1000000000000000_type2modifiedrep_base10             |  88.17   |    1.74     |  88.17   |     1.74     |
# |                       max-1000000_rep3_base-10                        |  99.77   |    0.01     |  98.89   |     0.04     |
# |                    one-step_maxint-100000-training                    |  100.00  |    0.00     |  100.00  |     0.00     |
# |              one-step_maxint-100000-training_eval1000000              |  71.07   |    13.80    |  69.57   |    28.80     |
# |                  one-step_maxint10000000000-training                  |  99.03   |    0.07     |  98.80   |     0.12     |
# |          one-step_train10000000000-training_eval100000000000          |  82.97   |    18.69    |  81.83   |    22.33     |
# |               one-step_maxint100000-dropout0.2-training               |  100.00  |    0.01     |  100.00  |     0.01     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |  70.43   |    15.04    |  68.47   |    29.65     |
# |               one-step_maxint100000-dropout0.2-training               |  99.40   |    0.04     |  99.40   |     0.04     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |  70.63   |    14.00    |  70.63   |    27.28     |
# |               one-step_maxint100000-dropout0.5-training               |  99.57   |    0.03     |  99.57   |     0.03     |
# |         one-step_train100000-dropout0.5-training_eval1000000          |  69.80   |    13.91    |  69.80   |    28.49     |
# |     one-step_maxint100000-dropout0.5-attentionDropOut0.5-training     |  98.83   |    0.08     |  98.83   |     0.08     |
# | one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 |  69.80   |    14.20    |  69.80   |    29.72     |
# |          one-step_maxint100000-attentionDropOut0.5-training           |  99.97   |    0.02     |  99.97   |     0.02     |
# |      one-step_train100000-attentionDropOut-training_eval1000000       |  70.37   |    14.42    |  69.27   |    31.94     |
# +-----------------------------------------------------------------------+----------+-------------+----------+--------------+
# acc
# perfect
# correct
# xe_loss
# train_loss
# acc_6
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+
# |                                exp_id                                 | first epoch | best_acc | best_xeloss | last_acc | last_xe_loss |
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+
# |                       max-1000000_rep3_base-10                        |      0      |  99.77   |    0.01     |  98.89   |     0.04     |
# |            maxint1000000000000000_type3modifiedrep_base10             |      4      |  99.41   |    0.04     |  98.30   |     0.07     |
# |               one-step_maxint100000-dropout0.2-training               |      4      |  100.00  |    0.01     |  100.00  |     0.01     |
# |                    one-step_maxint-100000-training                    |      6      |  100.00  |    0.00     |  100.00  |     0.00     |
# |               one-step_maxint100000-dropout0.2-training               |      6      |  99.40   |    0.04     |  99.40   |     0.04     |
# |                  one-step_maxint10000000000-training                  |      7      |  99.03   |    0.07     |  98.80   |     0.12     |
# |               one-step_maxint100000-dropout0.5-training               |     12      |  99.57   |    0.03     |  99.57   |     0.03     |
# |          one-step_maxint100000-attentionDropOut0.5-training           |     22      |  99.97   |    0.02     |  99.97   |     0.02     |
# |                    max-1000000_default-rep_base-10                    |    10000    |  96.24   |    0.20     |  96.24   |     0.20     |
# |               max-1000000000000000_default-rep_base-10                |    10000    |  96.93   |    0.42     |  96.93   |     0.42     |
# |                         max-10000-default-rep                         |    10000    |   5.85   |    3.40     |   5.85   |     3.40     |
# |               maxint1000000000000000_default-rep_base2                |    10000    |   0.00   |    30.30    |   0.00   |    30.30     |
# |                 maxint1000000_type2modifiedrep_base10                 |    10000    |  95.68   |    0.19     |  95.68   |     0.19     |
# |            maxint1000000000000000_type2modifiedrep_base10             |    10000    |  88.17   |    1.74     |  88.17   |     1.74     |
# |              one-step_maxint-100000-training_eval1000000              |    10000    |  71.07   |    13.80    |  69.57   |    28.80     |
# |          one-step_train10000000000-training_eval100000000000          |    10000    |  82.97   |    18.69    |  81.83   |    22.33     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |    10000    |  70.43   |    15.04    |  68.47   |    29.65     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |    10000    |  70.63   |    14.00    |  70.63   |    27.28     |
# |         one-step_train100000-dropout0.5-training_eval1000000          |    10000    |  69.80   |    13.91    |  69.80   |    28.49     |
# |     one-step_maxint100000-dropout0.5-attentionDropOut0.5-training     |    10000    |  98.83   |    0.08     |  98.83   |     0.08     |
# | one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 |    10000    |  69.80   |    14.20    |  69.80   |    29.72     |
# |      one-step_train100000-attentionDropOut-training_eval1000000       |    10000    |  70.37   |    14.42    |  69.27   |    31.94     |
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+
# |                                exp_id                                 | first epoch | best_acc | best_xeloss | last_acc | last_xe_loss |
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+
# |                    max-1000000_default-rep_base-10                    |      0      |  96.24   |    0.20     |  96.24   |     0.20     |
# |                 maxint1000000_type2modifiedrep_base10                 |      0      |  95.68   |    0.19     |  95.68   |     0.19     |
# |                       max-1000000_rep3_base-10                        |      0      |  99.77   |    0.01     |  98.89   |     0.04     |
# |               max-1000000000000000_default-rep_base-10                |      3      |  96.93   |    0.42     |  96.93   |     0.42     |
# |                    one-step_maxint-100000-training                    |      3      |  100.00  |    0.00     |  100.00  |     0.00     |
# |               one-step_maxint100000-dropout0.2-training               |      3      |  100.00  |    0.01     |  100.00  |     0.01     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |      3      |  70.43   |    15.04    |  68.47   |    29.65     |
# |            maxint1000000000000000_type3modifiedrep_base10             |      4      |  99.41   |    0.04     |  98.30   |     0.07     |
# |            maxint1000000000000000_type2modifiedrep_base10             |      4      |  88.17   |    1.74     |  88.17   |     1.74     |
# |              one-step_maxint-100000-training_eval1000000              |      4      |  71.07   |    13.80    |  69.57   |    28.80     |
# |               one-step_maxint100000-dropout0.2-training               |      4      |  99.40   |    0.04     |  99.40   |     0.04     |
# |         one-step_train100000-dropout0.2-training_eval1000000          |      4      |  70.63   |    14.00    |  70.63   |    27.28     |
# |                  one-step_maxint10000000000-training                  |      6      |  99.03   |    0.07     |  98.80   |     0.12     |
# |          one-step_train10000000000-training_eval100000000000          |      6      |  82.97   |    18.69    |  81.83   |    22.33     |
# |               one-step_maxint100000-dropout0.5-training               |      7      |  99.57   |    0.03     |  99.57   |     0.03     |
# |         one-step_train100000-dropout0.5-training_eval1000000          |      8      |  69.80   |    13.91    |  69.80   |    28.49     |
# |     one-step_maxint100000-dropout0.5-attentionDropOut0.5-training     |     11      |  98.83   |    0.08     |  98.83   |     0.08     |
# |          one-step_maxint100000-attentionDropOut0.5-training           |     12      |  99.97   |    0.02     |  99.97   |     0.02     |
# | one-step_train100000-dropout0.5-attentionDropOut-training_eval1000000 |     14      |  69.80   |    14.20    |  69.80   |    29.72     |
# |      one-step_train100000-attentionDropOut-training_eval1000000       |     16      |  70.37   |    14.42    |  69.27   |    31.94     |
# |                         max-10000-default-rep                         |    10000    |   5.85   |    3.40     |   5.85   |     3.40     |
# |               maxint1000000000000000_default-rep_base2                |    10000    |   0.00   |    30.30    |   0.00   |    30.30     |
# +-----------------------------------------------------------------------+-------------+----------+-------------+----------+--------------+

# %%
import csv
import itertools

stat_categories = ["acc", "perfect", "correct", "xe_loss", "train_loss"]
#... probably doesn't make senes to have train loss be in the same fiel as the others.... :D
# run seperately ig.

for d in data:
  stats = [];
  if (d['xp']=='.ipynb_checkpoints'):#temp fix.... i mean idk if we're usin this but if we are should try to get why it's doing this now...
    continue
  for category in stat_categories:
    stats.append(d[category])

  with open(d["env"] + "-" + d["xp"] + '-'+ "data" + ".csv", 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(stat_categories)
    for i in itertools.zip_longest(*stats):
      wr.writerow(list(i))
